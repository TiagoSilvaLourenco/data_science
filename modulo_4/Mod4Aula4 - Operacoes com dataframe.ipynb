# %%
import numpy  as np
import pandas as pd

# %% [markdown]
# # Operações com ``DataFrame``

# %% [markdown]
# ## Criando 2 dataframes (3 x 5)

# %%
np.random.randint(10, size=(3, 5))
# Out:
# array([[7, 8, 1, 8, 0],
#        [4, 8, 9, 6, 9],
#        [4, 5, 4, 2, 9]])

# %%
df1 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df1
# Out:
#    A  B  C  D  E
# 0  8  1  0  6  4
# 1  1  8  9  1  7
# 2  2  1  9  8  9

# %%
df2 = pd.DataFrame(np.random.randint(10, size=(3, 5)), columns=['A','B','C','D','E'])
df2
# Out:
#    A  B  C  D  E
# 0  6  2  7  0  0
# 1  8  6  6  7  3
# 2  3  1  4  5  9

# %% [markdown]
# ## Somando 2 dataframes (3 x 5)

# %%
df1 + df2
# Out:
#     A   B   C   D   E
# 0  14   3   7   6   4
# 1   9  14  15   8  10
# 2   5   2  13  13  18

# %% [markdown]
# ## Criando 1 dataframe (1 x 5)

# %%
df3 = pd.DataFrame(np.random.randint(10, size=(1, 5)), columns=['A','B','C','D','E'])
df3
# Out:
#    A  B  C  D  E
# 0  2  4  6  2  9

# %% [markdown]
# ## Somando 2 dataframes (3 x 5 e 1 x 5)

# %%
df1 + df3
# Out:
#       A    B    C    D     E
# 0  10.0  5.0  6.0  8.0  13.0
# 1   NaN  NaN  NaN  NaN   NaN
# 2   NaN  NaN  NaN  NaN   NaN

# %% [markdown]
# ## Zerando uma linha

# %%
df1
# Out:
#    A  B  C  D  E
# 0  8  1  0  6  4
# 1  1  8  9  1  7
# 2  2  1  9  8  9

# %%
df1.iloc[0]
# Out:
# A    8
# B    1
# C    0
# D    6
# E    4
# Name: 0, dtype: int64

# %%
df1 - df1.iloc[0]
# Out:
#    A  B  C  D  E
# 0  0  0  0  0  0
# 1 -7  7  9 -5  3
# 2 -6  0  9  2  5

# %% [markdown]
# ## Operação com escalar

# %%
df1
# Out:
#    A  B  C  D  E
# 0  8  1  0  6  4
# 1  1  8  9  1  7
# 2  2  1  9  8  9

# %%
df1 * 100
# Out:
#      A    B    C    D    E
# 0  800  100    0  600  400
# 1  100  800  900  100  700
# 2  200  100  900  800  900

# %%
df1 * 100 + 200
# Out:
#       A     B     C     D     E
# 0  1000   300   200   800   600
# 1   300  1000  1100   300   900
# 2   400   300  1100  1000  1100

# %% [markdown]
# ## Transpondo df

# %%
df1
# Out:
#    A  B  C  D  E
# 0  8  1  0  6  4
# 1  1  8  9  1  7
# 2  2  1  9  8  9

# %%
df1.T
# Out:
#    0  1  2
# A  8  1  2
# B  1  8  1
# C  0  9  9
# D  6  1  8
# E  4  7  9

# %% [markdown]
# ## Calculando exponencial dos valores

# %%
np.exp(df1)
# Out:
#              A            B            C            D            E
# 0  2980.957987     2.718282     1.000000   403.428793    54.598150
# 1     2.718282  2980.957987  8103.083928     2.718282  1096.633158
# 2     7.389056     2.718282  8103.083928  2980.957987  8103.083928

# %% [markdown]
# # Registros de Vacinação COVID19 (Acre)
#
# link: https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/ef3bd0b8-b605-474b-9ae5-c97390c197a8

# %% [markdown]
# ## Lendo CSV

# %%
vacAcre = pd.read_csv(
    'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-587cb4f5-6a99-4e87-b9c0-988c536d2846.c000.csv',
    sep=';')
vacAcre
# Out:
# /tmp/ipykernel_4427/1543787690.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   vacAcre = pd.read_csv(
#                                       document_id  \
# 0       9ff97f62-ece8-4ff6-9c9e-6e63a006276f-i0b0
# 1       24f0228b-b3ef-418e-a752-3dd760390219-i0b0
# 2       cbffb062-36f7-425d-9531-0e508c813c47-i0b0
# 3       25069d59-5d14-40e8-9b9c-e4c97eb88fda-i0b0
# 4       09e41ae9-32b3-42e8-80ab-7d193ff7b7dd-i0b0
# ...                                           ...
# 554723  3c1e33f5-04e9-4608-92db-448bc32737c1-i0b0
# 554724  3c28a47d-281e-4df2-a14f-043da54e002f-i0b0
# 554725  3c3a5ce5-1e45-4ca3-a1cf-7c79d5031b3b-i0b0
# 554726  3c814989-eb24-4ebd-96ab-bc143137b8fc-i0b0
# 554727  3c97919e-0dfc-4183-b2c8-98dee06c9b89-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       efa3f81bc7e88f644dd0c7e006e105f0bdbe4cbe820289...            32.0
# 1       f9920b3f86ecce123479664d091e060bc1c156b7afcea2...            60.0
# 2       0e9a0dd31380a1b63fe7ed23fd72e6d7246d8389f843b4...            53.0
# 3       6d2d672b7c670d6546db0f90ccb69f39fc8549c56c1832...            26.0
# 4       14087041a341c63d25c82cec959bf0b886a4e91473c437...            21.0
# ...                                                   ...             ...
# 554723  954c3ef55fe8827a062c79609d349b78ae40d0d290abb9...            25.0
# 554724  f8968c7d584a4a4d5911c8981bd1fd1229869a9ba97901...            38.0
# 554725  e1b3c105501b08e56fc6012f336fe64ffe5dd372157cd3...             9.0
# 554726  d26c4de9c68f68bc372b826eaefef14d9ee72cdf77cc70...            25.0
# 554727  95e467da82da5678c8d7f848c6268d4ca8aa4cc53f972b...            33.0
#
#        paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                   1988-11-11                          F
# 1                   1961-10-24                          M
# 2                   1967-12-24                          F
# 3                   1994-09-07                          F
# 4                   2000-02-08                          F
# ...                        ...                        ...
# 554723              1996-12-03                          M
# 554724              1983-01-26                          F
# 554725              2012-05-09                          M
# 554726              1996-06-11                          M
# 554727              1988-06-26                          M
#
#         paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                           4.0                AMARELA
# 1                           3.0                  PARDA
# 2                           3.0                  PARDA
# 3                           1.0                 BRANCA
# 4                           4.0                AMARELA
# ...                         ...                    ...
# 554723                      4.0                AMARELA
# 554724                      3.0                  PARDA
# 554725                      3.0                  PARDA
# 554726                      4.0                AMARELA
# 554727                      3.0                  PARDA
#
#        paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 0                               120070.0                     10.0
# 1                               120040.0                     10.0
# 2                               120010.0                     10.0
# 3                               120040.0                     10.0
# 4                               120040.0                     10.0
# ...                                  ...                      ...
# 554723                            120040                       10
# 554724                            120039                       10
# 554725                            120040                       10
# 554726                            120040                       10
# 554727                            120020                       10
#
#        paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                             XAPURI  ...                     2.0
# 1                         RIO BRANCO  ...                     1.0
# 2                          BRASILEIA  ...                     2.0
# 3                         RIO BRANCO  ...                    21.0
# 4                         RIO BRANCO  ...                     2.0
# ...                              ...  ...                     ...
# 554723                    RIO BRANCO  ...                     2.0
# 554724                  PORTO WALTER  ...                     2.0
# 554725                    RIO BRANCO  ...                     NaN
# 554726                    RIO BRANCO  ...                     2.0
# 554727               CRUZEIRO DO SUL  ...                     2.0
#
#        vacina_categoria_nome  vacina_lote  vacina_fabricante_nome  \
# 0               Faixa Etária       210198             ASTRAZENECA
# 1               Comorbidades   217VCD239Z     ASTRAZENECA/FIOCRUZ
# 2               Faixa Etária   215VCD120W     ASTRAZENECA/FIOCRUZ
# 3                  Gestantes       FC2495                  PFIZER
# 4               Faixa Etária       FF5107                  PFIZER
# ...                      ...          ...                     ...
# 554723          Faixa Etária      212J21A                 JANSSEN
# 554724          Faixa Etária  215VCD011VA     ASTRAZENECA/FIOCRUZ
# 554725                   NaN       FN5988  Pendente Identificação
# 554726          Faixa Etária   217VCD231W     ASTRAZENECA/FIOCRUZ
# 554727          Faixa Etária   216VCD213W     ASTRAZENECA/FIOCRUZ
#
#         vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                 Organization/29909           2021-08-25
# 1                   Organization/149           2022-01-19
# 2        Organization/33781055000135           2021-06-18
# 3        Organization/00394544000851           2021-06-21
# 4        Organization/00394544000851           2021-09-24
# ...                              ...                  ...
# 554723                         30587           2022-06-16
# 554724   Organization/33781055000135           2021-07-07
# 554725            Organization/28290           2022-04-09
# 554726   Organization/33781055000135           2021-09-20
# 554727   Organization/33781055000135           2021-08-05
#
#        vacina_descricao_dose  vacina_codigo  \
# 0                    2ª Dose             89
# 1                    Reforço             85
# 2                    1ª Dose             85
# 3                    1ª Dose             87
# 4                    2ª Dose             87
# ...                      ...            ...
# 554723               Reforço             88
# 554724               1ª Dose             85
# 554725               1ª Dose             99
# 554726               2ª Dose             85
# 554727               2ª Dose             85
#
#                                       vacina_nome sistema_origem
# 0                COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 1       COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 2       COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 3                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                     COVID-19 PFIZER - COMIRNATY       Novo PNI
# ...                                           ...            ...
# 554723             COVID-19 JANSSEN - Ad26.COV2.S       Novo PNI
# 554724  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 554725     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY       Novo PNI
# 554726  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 554727  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
# [554728 rows x 32 columns]

# %%
vacAcre.head()
# Out:
#                                  document_id  \
# 0  9ff97f62-ece8-4ff6-9c9e-6e63a006276f-i0b0
# 1  24f0228b-b3ef-418e-a752-3dd760390219-i0b0
# 2  cbffb062-36f7-425d-9531-0e508c813c47-i0b0
# 3  25069d59-5d14-40e8-9b9c-e4c97eb88fda-i0b0
# 4  09e41ae9-32b3-42e8-80ab-7d193ff7b7dd-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  efa3f81bc7e88f644dd0c7e006e105f0bdbe4cbe820289...            32.0
# 1  f9920b3f86ecce123479664d091e060bc1c156b7afcea2...            60.0
# 2  0e9a0dd31380a1b63fe7ed23fd72e6d7246d8389f843b4...            53.0
# 3  6d2d672b7c670d6546db0f90ccb69f39fc8549c56c1832...            26.0
# 4  14087041a341c63d25c82cec959bf0b886a4e91473c437...            21.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1988-11-11                          F                      4.0
# 1              1961-10-24                          M                      3.0
# 2              1967-12-24                          F                      3.0
# 3              1994-09-07                          F                      1.0
# 4              2000-02-08                          F                      4.0
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                          120070.0
# 1                  PARDA                          120040.0
# 2                  PARDA                          120010.0
# 3                 BRANCA                          120040.0
# 4                AMARELA                          120040.0
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                     10.0                        XAPURI  ...
# 1                     10.0                    RIO BRANCO  ...
# 2                     10.0                     BRASILEIA  ...
# 3                     10.0                    RIO BRANCO  ...
# 4                     10.0                    RIO BRANCO  ...
#
#   vacina_categoria_codigo vacina_categoria_nome vacina_lote  \
# 0                     2.0          Faixa Etária      210198
# 1                     1.0          Comorbidades  217VCD239Z
# 2                     2.0          Faixa Etária  215VCD120W
# 3                    21.0             Gestantes      FC2495
# 4                     2.0          Faixa Etária      FF5107
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0            ASTRAZENECA            Organization/29909           2021-08-25
# 1    ASTRAZENECA/FIOCRUZ              Organization/149           2022-01-19
# 2    ASTRAZENECA/FIOCRUZ   Organization/33781055000135           2021-06-18
# 3                 PFIZER   Organization/00394544000851           2021-06-21
# 4                 PFIZER   Organization/00394544000851           2021-09-24
#
#   vacina_descricao_dose  vacina_codigo  \
# 0               2ª Dose             89
# 1               Reforço             85
# 2               1ª Dose             85
# 3               1ª Dose             87
# 4               2ª Dose             87
#
#                                  vacina_nome sistema_origem
# 0           COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 1  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 2  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 3                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Verificando dataframe

# %%
vacAcre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554728 entries, 0 to 554727
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               554728 non-null  object
#  1   paciente_id                               554727 non-null  object
#  2   paciente_idade                            554727 non-null  float64
#  3   paciente_dataNascimento                   554727 non-null  object
#  4   paciente_enumSexoBiologico                554727 non-null  object
#  5   paciente_racaCor_codigo                   554727 non-null  float64
#  6   paciente_racaCor_valor                    554727 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         551353 non-null  object
#  8   paciente_endereco_coPais                  551360 non-null  object
#  9   paciente_endereco_nmMunicipio             551359 non-null  object
#  10  paciente_endereco_nmPais                  551360 non-null  object
#  11  paciente_endereco_uf                      551353 non-null  object
#  12  paciente_endereco_cep                     496980 non-null  object
#  13  paciente_nacionalidade_enumNacionalidade  554531 non-null  object
#  14  estabelecimento_valor                     554728 non-null  int64
#  15  estabelecimento_razaoSocial               554728 non-null  object
#  16  estalecimento_noFantasia                  554728 non-null  object
#  17  estabelecimento_municipio_codigo          554728 non-null  int64
#  18  estabelecimento_municipio_nome            554728 non-null  object
#  19  estabelecimento_uf                        554728 non-null  object
#  20  vacina_grupoAtendimento_codigo            554706 non-null  float64
#  21  vacina_grupoAtendimento_nome              553773 non-null  object
#  22  vacina_categoria_codigo                   522819 non-null  float64
#  23  vacina_categoria_nome                     522819 non-null  object
#  24  vacina_lote                               554728 non-null  object
#  25  vacina_fabricante_nome                    554728 non-null  object
#  26  vacina_fabricante_referencia              551520 non-null  object
#  27  vacina_dataAplicacao                      554728 non-null  object
#  28  vacina_descricao_dose                     554728 non-null  object
#  29  vacina_codigo                             554728 non-null  int64
#  30  vacina_nome                               554714 non-null  object
#  31  sistema_origem                            554187 non-null  object
# dtypes: float64(4), int64(3), object(25)
# memory usage: 135.4+ MB

# %% [markdown]
# ## Copiando parte do dataframe

# %%
vacAcre_copy = vacAcre[:20000].copy()
vacAcre_copy
# Out:
#                                      document_id  \
# 0      9ff97f62-ece8-4ff6-9c9e-6e63a006276f-i0b0
# 1      24f0228b-b3ef-418e-a752-3dd760390219-i0b0
# 2      cbffb062-36f7-425d-9531-0e508c813c47-i0b0
# 3      25069d59-5d14-40e8-9b9c-e4c97eb88fda-i0b0
# 4      09e41ae9-32b3-42e8-80ab-7d193ff7b7dd-i0b0
# ...                                          ...
# 19995  221983d4-7b4e-4f54-883f-b0ddb238151b-i0b0
# 19996  e4be1f40-e9ae-4f21-aa5e-fe06281ed163-i0b0
# 19997  e3a532bc-ef96-4126-904b-6b62a2836897-i0b0
# 19998  4d5f6fc5-33b4-455d-a621-de3215ccd1bc-i0b0
# 19999  5919df05-5603-43d5-b30b-c231a43f86f8-i0b0
#
#                                              paciente_id  paciente_idade  \
# 0      efa3f81bc7e88f644dd0c7e006e105f0bdbe4cbe820289...            32.0
# 1      f9920b3f86ecce123479664d091e060bc1c156b7afcea2...            60.0
# 2      0e9a0dd31380a1b63fe7ed23fd72e6d7246d8389f843b4...            53.0
# 3      6d2d672b7c670d6546db0f90ccb69f39fc8549c56c1832...            26.0
# 4      14087041a341c63d25c82cec959bf0b886a4e91473c437...            21.0
# ...                                                  ...             ...
# 19995  317023ce5b1d063ea9bbb77adc6f880f03a3027420428b...            35.0
# 19996  bea94d47fe1c03001e2a4b56c538d2f79babc7d361ddce...            40.0
# 19997  6f9cf5e25abb086c2dfa78aee98b419ef6ac34054c2785...            25.0
# 19998  917a2d46ac473a5796597a30bfc9901b8edaac2310bf70...            39.0
# 19999  185c2ac0fdb25df268b5969477ad04efa78e25ad876646...            33.0
#
#       paciente_dataNascimento paciente_enumSexoBiologico  \
# 0                  1988-11-11                          F
# 1                  1961-10-24                          M
# 2                  1967-12-24                          F
# 3                  1994-09-07                          F
# 4                  2000-02-08                          F
# ...                       ...                        ...
# 19995              1985-11-26                          M
# 19996              1981-05-19                          M
# 19997              1997-02-28                          F
# 19998              1982-02-28                          F
# 19999              1988-05-05                          F
#
#        paciente_racaCor_codigo paciente_racaCor_valor  \
# 0                          4.0                AMARELA
# 1                          3.0                  PARDA
# 2                          3.0                  PARDA
# 3                          1.0                 BRANCA
# 4                          4.0                AMARELA
# ...                        ...                    ...
# 19995                      4.0                AMARELA
# 19996                     99.0         SEM INFORMACAO
# 19997                      3.0                  PARDA
# 19998                      1.0                 BRANCA
# 19999                      3.0                  PARDA
#
#       paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 0                              120070.0                     10.0
# 1                              120040.0                     10.0
# 2                              120010.0                     10.0
# 3                              120040.0                     10.0
# 4                              120040.0                     10.0
# ...                                 ...                      ...
# 19995                          110045.0                     10.0
# 19996                          120045.0                     10.0
# 19997                          120001.0                     10.0
# 19998                          120045.0                     10.0
# 19999                          120040.0                     10.0
#
#       paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 0                            XAPURI  ...                     2.0
# 1                        RIO BRANCO  ...                     1.0
# 2                         BRASILEIA  ...                     2.0
# 3                        RIO BRANCO  ...                    21.0
# 4                        RIO BRANCO  ...                     2.0
# ...                             ...  ...                     ...
# 19995                       BURITIS  ...                     2.0
# 19996              SENADOR GUIOMARD  ...                     2.0
# 19997                    ACRELANDIA  ...                     2.0
# 19998              SENADOR GUIOMARD  ...                     9.0
# 19999                    RIO BRANCO  ...                     2.0
#
#         vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 0                Faixa Etária      210198            ASTRAZENECA
# 1                Comorbidades  217VCD239Z    ASTRAZENECA/FIOCRUZ
# 2                Faixa Etária  215VCD120W    ASTRAZENECA/FIOCRUZ
# 3                   Gestantes      FC2495                 PFIZER
# 4                Faixa Etária      FF5107                 PFIZER
# ...                       ...         ...                    ...
# 19995            Faixa Etária      210040       SINOVAC/BUTANTAN
# 19996            Faixa Etária      FJ4187                 PFIZER
# 19997            Faixa Etária      FP8073                 PFIZER
# 19998  Trabalhadores de Saúde      FJ4187                 PFIZER
# 19999            Faixa Etária      EY0586                 PFIZER
#
#        vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                Organization/29909           2021-08-25
# 1                  Organization/149           2022-01-19
# 2       Organization/33781055000135           2021-06-18
# 3       Organization/00394544000851           2021-06-21
# 4       Organization/00394544000851           2021-09-24
# ...                             ...                  ...
# 19995   Organization/61189445000156           2021-06-26
# 19996            Organization/28290           2022-01-24
# 19997                         28290           2022-07-19
# 19998            Organization/28290           2022-01-06
# 19999   Organization/00394544000851           2021-07-08
#
#       vacina_descricao_dose  vacina_codigo  \
# 0                   2ª Dose             89
# 1                   Reforço             85
# 2                   1ª Dose             85
# 3                   1ª Dose             87
# 4                   2ª Dose             87
# ...                     ...            ...
# 19995               1ª Dose             86
# 19996               Reforço             87
# 19997               Reforço             87
# 19998               Reforço             87
# 19999               1ª Dose             87
#
#                                      vacina_nome sistema_origem
# 0               COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 1      COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 2      COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 3                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4                    COVID-19 PFIZER - COMIRNATY       Novo PNI
# ...                                          ...            ...
# 19995      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 19996                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19997                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19998                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 19999                COVID-19 PFIZER - COMIRNATY       Novo PNI
#
# [20000 rows x 32 columns]

# %% [markdown]
# ## Qual o percentual das vacinas aplicadas foram na capital???

# %%
vacAcre_copy['fl_capital'] = 0

# %%
vacAcre_copy.head(2)
# Out:
#                                  document_id  \
# 0  9ff97f62-ece8-4ff6-9c9e-6e63a006276f-i0b0
# 1  24f0228b-b3ef-418e-a752-3dd760390219-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  efa3f81bc7e88f644dd0c7e006e105f0bdbe4cbe820289...            32.0
# 1  f9920b3f86ecce123479664d091e060bc1c156b7afcea2...            60.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1988-11-11                          F                      4.0
# 1              1961-10-24                          M                      3.0
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                          120070.0
# 1                  PARDA                          120040.0
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                     10.0                        XAPURI  ...
# 1                     10.0                    RIO BRANCO  ...
#
#   vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 0          Faixa Etária      210198            ASTRAZENECA
# 1          Comorbidades  217VCD239Z    ASTRAZENECA/FIOCRUZ
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0           Organization/29909            2021-08-25               2ª Dose
# 1             Organization/149            2022-01-19               Reforço
#
#   vacina_codigo                                vacina_nome sistema_origem  \
# 0            89           COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 1            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
#
#   fl_capital
# 0          0
# 1          0
#
# [2 rows x 33 columns]

# %%
vacAcre_copy.loc[vacAcre_copy['paciente_endereco_nmMunicipio'] == 'RIO BRANCO', 'fl_capital'] = 1

# %%
vacAcre_copy.head(10)
# Out:
#                                  document_id  \
# 0  9ff97f62-ece8-4ff6-9c9e-6e63a006276f-i0b0
# 1  24f0228b-b3ef-418e-a752-3dd760390219-i0b0
# 2  cbffb062-36f7-425d-9531-0e508c813c47-i0b0
# 3  25069d59-5d14-40e8-9b9c-e4c97eb88fda-i0b0
# 4  09e41ae9-32b3-42e8-80ab-7d193ff7b7dd-i0b0
# 5  25088d3f-f517-4dd3-8fc4-bd967357808c-i0b0
# 6  3e820062-2fb4-4a28-b0d1-8da2b93f555f-i0b0
# 7  25150148-a59b-4b8e-91f2-ad6ed511f983-i0b0
# 8  6656d578-b9cf-4ce2-994b-0b36c44f6cf7-i0b0
# 9  25d70a6d-efd5-42be-96db-4b5bbc75732f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  efa3f81bc7e88f644dd0c7e006e105f0bdbe4cbe820289...            32.0
# 1  f9920b3f86ecce123479664d091e060bc1c156b7afcea2...            60.0
# 2  0e9a0dd31380a1b63fe7ed23fd72e6d7246d8389f843b4...            53.0
# 3  6d2d672b7c670d6546db0f90ccb69f39fc8549c56c1832...            26.0
# 4  14087041a341c63d25c82cec959bf0b886a4e91473c437...            21.0
# 5  63d7cec3f5f07b1be78ca70b17bd7125210f107651ac5b...            32.0
# 6  0e2be9ac87390639c0e40d192dcf5652592a98a129a182...            49.0
# 7  769ca14ff55bdf60fb599940053d4dcf065710a352ee9a...            46.0
# 8  6389b7f120217a570538fc3cb7d00b754110db4539cac2...            78.0
# 9  0180c97016a42c94459a00d29a9ce65c59dff50f64eb96...            70.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1988-11-11                          F                      4.0
# 1              1961-10-24                          M                      3.0
# 2              1967-12-24                          F                      3.0
# 3              1994-09-07                          F                      1.0
# 4              2000-02-08                          F                      4.0
# 5              1989-09-01                          M                      4.0
# 6              1971-10-10                          M                      4.0
# 7              1974-10-19                          F                      3.0
# 8              1943-02-11                          F                      4.0
# 9              1950-06-13                          M                      4.0
#
#   paciente_racaCor_valor paciente_endereco_coIbgeMunicipio  \
# 0                AMARELA                          120070.0
# 1                  PARDA                          120040.0
# 2                  PARDA                          120010.0
# 3                 BRANCA                          120040.0
# 4                AMARELA                          120040.0
# 5                AMARELA                          120040.0
# 6                AMARELA                          120033.0
# 7                  PARDA                          120010.0
# 8                AMARELA                          120040.0
# 9                AMARELA                          120033.0
#
#   paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                     10.0                        XAPURI  ...
# 1                     10.0                    RIO BRANCO  ...
# 2                     10.0                     BRASILEIA  ...
# 3                     10.0                    RIO BRANCO  ...
# 4                     10.0                    RIO BRANCO  ...
# 5                     10.0                    RIO BRANCO  ...
# 6                     10.0                   MANCIO LIMA  ...
# 7                     10.0                     BRASILEIA  ...
# 8                     10.0                    RIO BRANCO  ...
# 9                     10.0                   MANCIO LIMA  ...
#
#   vacina_categoria_nome vacina_lote vacina_fabricante_nome  \
# 0          Faixa Etária      210198            ASTRAZENECA
# 1          Comorbidades  217VCD239Z    ASTRAZENECA/FIOCRUZ
# 2          Faixa Etária  215VCD120W    ASTRAZENECA/FIOCRUZ
# 3             Gestantes      FC2495                 PFIZER
# 4          Faixa Etária      FF5107                 PFIZER
# 5          Faixa Etária      FH4750                 PFIZER
# 6          Faixa Etária      210135       SINOVAC/BUTANTAN
# 7          Faixa Etária      FA9090                 PFIZER
# 8          Faixa Etária    4120Z025    ASTRAZENECA/FIOCRUZ
# 9          Faixa Etária     210052A       SINOVAC/BUTANTAN
#
#   vacina_fabricante_referencia  vacina_dataAplicacao vacina_descricao_dose  \
# 0           Organization/29909            2021-08-25               2ª Dose
# 1             Organization/149            2022-01-19               Reforço
# 2  Organization/33781055000135            2021-06-18               1ª Dose
# 3  Organization/00394544000851            2021-06-21               1ª Dose
# 4  Organization/00394544000851            2021-09-24               2ª Dose
# 5           Organization/28290            2021-11-26               2ª Dose
# 6  Organization/61189445000156            2021-06-29               1ª Dose
# 7  Organization/00394544000851            2021-07-09               1ª Dose
# 8  Organization/33781055000135            2021-02-26               1ª Dose
# 9  Organization/61189445000156            2021-04-09               2ª Dose
#
#   vacina_codigo                                vacina_nome sistema_origem  \
# 0            89           COVID-19 ASTRAZENECA - ChAdOx1-S       Novo PNI
# 1            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 2            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 3            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 4            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 5            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 6            86      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
# 7            87                COVID-19 PFIZER - COMIRNATY       Novo PNI
# 8            85  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD       Novo PNI
# 9            86      COVID-19 SINOVAC/BUTANTAN - CORONAVAC       Novo PNI
#
#   fl_capital
# 0          0
# 1          1
# 2          0
# 3          1
# 4          1
# 5          1
# 6          0
# 7          0
# 8          1
# 9          0
#
# [10 rows x 33 columns]

# %%
vacAcre_copy[['paciente_endereco_nmMunicipio','fl_capital']]
# Out:
#       paciente_endereco_nmMunicipio  fl_capital
# 0                            XAPURI           0
# 1                        RIO BRANCO           1
# 2                         BRASILEIA           0
# 3                        RIO BRANCO           1
# 4                        RIO BRANCO           1
# ...                             ...         ...
# 19995                       BURITIS           0
# 19996              SENADOR GUIOMARD           0
# 19997                    ACRELANDIA           0
# 19998              SENADOR GUIOMARD           0
# 19999                    RIO BRANCO           1
#
# [20000 rows x 2 columns]

# %%
vacAcre_copy['fl_capital'].sum()
# Out:
# 9913

# %%
9294/20000
# Out:
# 0.4647

# %% [markdown]
# ## Qual a idade média dos pacientes???

# %%
vacAcre_copy['paciente_idade'].mean()
# Out:
# 37.1105
