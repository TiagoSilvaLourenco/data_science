# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sinasc = pd.read_csv('SINASC_RO_2019.csv')
print(sinasc.shape)

sinasc.drop_duplicates().shape
# Não há duplicados
# Out:
# (27028, 69)
# (27028, 69)

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
plt.close('all')
plt.rc('figure', figsize=(10, 8))
fig, axes = plt.subplots(3, 2)

sns.countplot(ax = axes[0, 0], x='APGAR1', data=sinasc)
sns.countplot(ax = axes[0, 1], x='APGAR5', data=sinasc)
sns.countplot(ax = axes[1, 0], x='SEXO', data=sinasc)
sns.countplot(ax = axes[1, 1], x='GESTACAO', data=sinasc)
sns.countplot(ax = axes[2, 0], x='ESTCIVMAE', data=sinasc)

plt.subplots_adjust(right=2, wspace=0.1, hspace=0.5)

axes.tick_params(axis="x", rotation = 30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12122/1815827755.py in <module>
#      11 plt.subplots_adjust(right=2, wspace=0.1, hspace=0.5)
#      12
# ---> 13 axes.tick_params(axis="x", rotation = 30)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'tick_params'

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize=(10,10))
fig, axes = plt.subplots(2,2)

sns.barplot(ax = axes[0,0], y='APGAR5', x='CONSULTAS', data=sinasc)
# sns.barplot(ax = axes[0,1], x='APGAR5', y='CONSULTAS', data=sinasc)
# Out:
# <AxesSubplot:xlabel='CONSULTAS', ylabel='APGAR5'>

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.close('all')
plt.rc('figure', figsize=(10,8))
fig, axes = plt.subplots(2,2)

sns.countplot(ax = axes[0, 0], x='SEXO', data=sinasc)
sns.countplot(ax = axes[0, 1], x='GESTACAO', orient='v', data=sinasc)
sns.countplot(ax = axes[1, 0], x='ESTCIVMAE', data=sinasc)
sns.countplot(ax = axes[1, 1], x='CONSULTAS', data=sinasc)

plt.subplots_adjust(right=2, wspace=0.1, hspace=0.5)
